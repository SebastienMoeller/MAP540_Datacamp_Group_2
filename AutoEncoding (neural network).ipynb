# %% [markdown]
# # Autoencoding try

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/viktormalesevic/Desktop/X/Capgemini Data Boot Camp/MAP540_Datacamp_Group_2/data_scraping.csv', encoding = 'ISO-8859-1', index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-6-4fcedba8b4fc> in <module>()
# ----> 1 data = pd.read_csv('/Users/viktormalesevic/Desktop/X/Capgemini Data Boot Camp/MAP540_Datacamp_Group_2/data_scraping.csv', encoding = 'ISO-8859-1', index_col = 0)
#
# ...
